# %% [markdown]
# ## Astrophysics data
# ### OpenIE providing (arg1, relation, arg2)
# ### Quantulum providing (value,unit,measure,quantity/surface) extractions

# %%
import numpy as np
import pandas as pd
from quantulum3 import parser
#import re
import spacy
#nlp = spacy.load('en_core_web_sm')
nlp = spacy.load("en_trf_bertbaseuncased_lg")
import unicodedata
#import neuralcoref
#neuralcoref.add_to_pipe(nlp)
#import gensim
#from sklearn.cluster import Birch
from sklearn import metrics
import csv
#import gensim.downloader as api

# %%
df = pd.read_csv('astro_analysis.csv', index_col=0)

# %%
len(df)
# Out:
# 7075

# %%
df.head(5)
# Out:
#                                             sentence  \
# 0  the likely elongated d-type asteroid has a rot...
# 1  the likely elongated d-type asteroid has a rot...
# 2  lightcurve analysis gave a well-defined rotati...
# 3  lightcurve analysis gave a well-defined rotati...
# 4  lightcurve analysis gave a well-defined rotati...
#
#                                    arg1      verb  \
# 0  the likely elongated d-type asteroid       has
# 1  the likely elongated d-type asteroid   belongs
# 2                   lightcurve analysis      gave
# 3                   lightcurve analysis      gave
# 4                       robert stephens  measured
#
#                          relation                            arg2 value_1  \
# 0               a rotation period                      8.48 hours    8.48
# 1                             NaN  the 50 largest jupiter trojans      50
# 2  a well-defined rotation period                     8.480 hours   8.480
# 3          a brightness variation                  0.58 magnitude    0.58
# 4          two concurring periods           8.461 and 8.470 hours   8.461
#
#                         unit_1 value_2 unit_2    q_measure_1  quantulum_v1  \
# 0                        hours     NaN    NaN           time        8.4800
# 1  the largest jupiter trojans     NaN    NaN  dimensionless       50.0000
# 2                        hours     NaN    NaN           time        8.4800
# 3                    magnitude     NaN    NaN  dimensionless        0.5800
# 4                        hours   8.470  hours           time        8.4655
#
#     quantulum_u1 q_measure_2  quantulum_v2 quantulum_u2
# 0           hour         NaN           NaN          NaN
# 1  dimensionless         NaN           NaN          NaN
# 2           hour         NaN           NaN          NaN
# 3  dimensionless         NaN           NaN          NaN
# 4           hour         NaN           NaN          NaN

# %%
df.groupby(["arg1","relation","unit"])['value'].agg(["min","max","count"]).sort_values("count", ascending=False).query("count > 10")
# Out:
#                                                                                                    min  \
# arg1                                       relation                 unit
# lightcurve analysis                        gave                     hour                       2.00000
# the collaborative asteroid lightcurve link derives                  kilometre                  2.18000
# the collaborative asteroid                 calculates               kilometre                  1.30000
# the main fields of work                    were                     year                      40.00000
# the bodys observation arc                  begins                   year                       1.00000
# the solar cycle                            lasted                   year                       9.30000
# the star                                   has                      count                      0.38000
# an extrasolar planet                       located                  light-year                55.00000
# the collaborative asteroid                 derives                  kilometre                  1.05000
# type asteroid                              has                      hour                       5.00000
# the s type asteroid                        has a rotation period of hour                       2.95000
# type asteroid                              has a rotation period of hour                       5.70000
# the planet                                 hd                       bit                    16175.00000
# an extrasolar planet                       orbits                   light-year                40.00000
# the japanese                               akari                    kilometre                 13.92000
# the asteroid                               measures                 kilometre                  1.86000
# the s-type asteroid                        has                      hour                       2.50000
# the s - type asteroid                      has                      hour                       3.30000
# this planet                                takes                    year                       0.90000
# the bodys observation arc                  begins                   day                        2.00000
# the stony s - type asteroid                has                      hour                       3.00000
# a network of astronomers worldwide         gathered                 second                  1990.00000
# a precovery                                taken                    year                       5.00000
# a modeled lightcurve                       gave                     hour                       5.94819
# two modeled lightcurves                    gave                     hour                       6.41368
# the collaborative asteroid lightcurve link assumes                  second short ton year      1.00000
#                                            adopts                   kilometre                  1.30000
# the solar photosphere                      contains                 percentage                 1.50000
# the x-type asteroid                        has                      hour                       3.40000
#
#                                                                                                     max  \
# arg1                                       relation                 unit
# lightcurve analysis                        gave                     hour                   4.880630e+02
# the collaborative asteroid lightcurve link derives                  kilometre              1.226500e+02
# the collaborative asteroid                 calculates               kilometre              1.628500e+02
# the main fields of work                    were                     year                   4.000000e+01
# the bodys observation arc                  begins                   year                   1.934000e+03
# the solar cycle                            lasted                   year                   1.360000e+01
# the star                                   has                      count                  6.700000e+00
# an extrasolar planet                       located                  light-year             2.000000e+04
# the collaborative asteroid                 derives                  kilometre              1.166600e+02
# type asteroid                              has                      hour                   9.300000e+01
# the s type asteroid                        has a rotation period of hour                   1.619000e+01
# type asteroid                              has a rotation period of hour                   2.498000e+01
# the planet                                 hd                       bit                    2.317010e+05
# an extrasolar planet                       orbits                   light-year             1.150617e+07
# the japanese                               akari                    kilometre              1.853000e+02
# the asteroid                               measures                 kilometre              1.850000e+01
# the s-type asteroid                        has                      hour                   1.300000e+02
# the s - type asteroid                      has                      hour                   1.280000e+02
# this planet                                takes                    year                   1.300000e+01
# the bodys observation arc                  begins                   day                    1.936000e+03
# the stony s - type asteroid                has                      hour                   9.740000e+01
# a network of astronomers worldwide         gathered                 second                 1.990000e+03
# a precovery                                taken                    year                   3.500000e+01
# a modeled lightcurve                       gave                     hour                   8.244400e+00
# two modeled lightcurves                    gave                     hour                   1.030708e+01
# the collaborative asteroid lightcurve link assumes                  second short ton year  1.000000e+00
#                                            adopts                   kilometre              1.423800e+02
# the solar photosphere                      contains                 percentage             8.700000e+01
# the x-type asteroid                        has                      hour                   1.940000e+01
#
#                                                                                            count
# arg1                                       relation                 unit
# lightcurve analysis                        gave                     hour                     266
# the collaborative asteroid lightcurve link derives                  kilometre                132
# the collaborative asteroid                 calculates               kilometre                124
# the main fields of work                    were                     year                      73
# the bodys observation arc                  begins                   year                      64
# the solar cycle                            lasted                   year                      36
# the star                                   has                      count                     36
# an extrasolar planet                       located                  light-year                34
# the collaborative asteroid                 derives                  kilometre                 32
# type asteroid                              has                      hour                      29
# the s type asteroid                        has a rotation period of hour                      26
# type asteroid                              has a rotation period of hour                      25
# the planet                                 hd                       bit                       24
# an extrasolar planet                       orbits                   light-year                24
# the japanese                               akari                    kilometre                 20
# the asteroid                               measures                 kilometre                 19
# the s-type asteroid                        has                      hour                      19
# the s - type asteroid                      has                      hour                      16
# this planet                                takes                    year                      14
# the bodys observation arc                  begins                   day                       14
# the stony s - type asteroid                has                      hour                      12
# a network of astronomers worldwide         gathered                 second                    12
# a precovery                                taken                    year                      12
# a modeled lightcurve                       gave                     hour                      12
# two modeled lightcurves                    gave                     hour                      12
# the collaborative asteroid lightcurve link assumes                  second short ton year     12
#                                            adopts                   kilometre                 12
# the solar photosphere                      contains                 percentage                11
# the x-type asteroid                        has                      hour                      11

# %% [markdown]
# Find mentions of s-type asteroids as arg1

# %%
df2 = df[df.arg1.str.contains('s[- ]+type +asteroid')]
df2
# Out:
#                                                sentence  \
# 12    the stony s-type asteroid has a rotation perio...
# 13    the stony s-type asteroid has a rotation perio...
# 152   the stony s-type asteroid has a notably short ...
# 243   the likely heavily elongated s-type asteroid h...
# 244   the likely heavily elongated s-type asteroid h...
# 272   former classification of planets shape model d...
# 325   the s-type asteroid has a rotation period of 3...
# 326   the s-type asteroid has a rotation period of 3...
# 352   the carbonaceous c-type asteroid (ch) has a lo...
# 546   the s-type asteroid has a rotation period of 3...
# 547   the s-type asteroid has a rotation period of 3...
# 583   the s-type asteroid has a rotation period of 1...
# 584   the s-type asteroid has a rotation period of 1...
# 670   the s-type asteroid has a rotation period of 1...
# 671   the s-type asteroid has a rotation period of 1...
# 686   the s-type asteroid has a rotation period of 1...
# 687   the s-type asteroid has a rotation period of 1...
# 696   the stony s-type asteroid has a rotation perio...
# 697   the stony s-type asteroid has a rotation perio...
# 956   the s-type asteroid has a rotation period of 1...
# 957   the s-type asteroid has a rotation period of 1...
# 1315  the s-type asteroid has a rotation period of 1...
# 1316  the s-type asteroid has a rotation period of 1...
# 1480  the stony s-type asteroid has a rotation perio...
# 1481  the stony s-type asteroid has a rotation perio...
# 1621  the s-type asteroid has a very long rotation p...
# 2017  the stony s-type asteroid has a long rotation ...
# 2018  the stony s-type asteroid has a long rotation ...
# 2158  the s-type asteroid has a rotation period of 9...
# 2159  the s-type asteroid has a rotation period of 9...
# ...                                                 ...
# 6672  the s-type asteroid has a rotation period of 4...
# 6673  the s-type asteroid has a rotation period of 4...
# 6689  the stony s-type asteroid has a rotation perio...
# 6690  the stony s-type asteroid has a rotation perio...
# 7021  the s-type asteroid has a rotation period of 7...
# 7022  the s-type asteroid has a rotation period of 7...
# 7136  the s-type asteroid has a rotation period of 7...
# 7137  the s-type asteroid has a rotation period of 7...
# 7315  the s-type asteroid has a rotation period of a...
# 7316  the s-type asteroid has a rotation period of a...
# 7419  the s-type asteroid has a long rotation period...
# 7420  the s-type asteroid has a long rotation period...
# 7435  the s-type asteroid has a rotation period of 5...
# 7436  the s-type asteroid has a rotation period of 5...
# 7706  the s-type asteroid has a short rotation perio...
# 7707  the s-type asteroid has a short rotation perio...
# 8051  the stony s-type asteroid has a rotation perio...
# 8052  the stony s-type asteroid has a rotation perio...
# 8092  the s-type asteroid has a short rotation perio...
# 8093  the s-type asteroid has a short rotation perio...
# 8385  the elongated s-type asteroid has a rotation p...
# 8386  the elongated s-type asteroid has a rotation p...
# 8457  the s-type asteroid (st/l) has a rotation peri...
# 8458  the s-type asteroid (st/l) has a rotation peri...
# 8804  the carbonaceous f-type asteroid (fc) has a ro...
# 8886  the common s-type asteroid has a rotation peri...
# 8887  the common s-type asteroid has a rotation peri...
# 8982  the carbonaceous c-type asteroid (cb) has a ro...
# 9026  the likely elongated s-type asteroid has a rot...
# 9027  the likely elongated s-type asteroid has a rot...
#
#                                                    arg1  \
# 12                            the stony s type asteroid
# 13                          the stony s - type asteroid
# 152                         the stony s - type asteroid
# 243        the likely heavily elongated s type asteroid
# 244      the likely heavily elongated s - type asteroid
# 272   former classification of planets shape model c...
# 325                                 the s type asteroid
# 326                               the s - type asteroid
# 352                      the carbonaceous type asteroid
# 546                                 the s type asteroid
# 547                                 the s-type asteroid
# 583                                 the s type asteroid
# 584                                 the s-type asteroid
# 670                                 the s type asteroid
# 671                               the s - type asteroid
# 686                                 the s type asteroid
# 687                                 the s-type asteroid
# 696                           the stony s type asteroid
# 697                         the stony s - type asteroid
# 956                                 the s type asteroid
# 957                               the s - type asteroid
# 1315                                the s type asteroid
# 1316                              the s - type asteroid
# 1480                          the stony s type asteroid
# 1481                        the stony s - type asteroid
# 1621                              the s - type asteroid
# 2017                          the stony s type asteroid
# 2018                        the stony s - type asteroid
# 2158                                the s type asteroid
# 2159                                the s-type asteroid
# ...                                                 ...
# 6672                                the s type asteroid
# 6673                                the s-type asteroid
# 6689                          the stony s type asteroid
# 6690                        the stony s - type asteroid
# 7021                                the s type asteroid
# 7022                                the s-type asteroid
# 7136                                the s type asteroid
# 7137                                the s-type asteroid
# 7315                                the s type asteroid
# 7316                                the s-type asteroid
# 7419                                the s type asteroid
# 7420                                the s-type asteroid
# 7435                                the s type asteroid
# 7436                              the s - type asteroid
# 7706                                the s type asteroid
# 7707                              the s - type asteroid
# 8051                          the stony s type asteroid
# 8052                          the stony s-type asteroid
# 8092                                the s type asteroid
# 8093                                the s-type asteroid
# 8385                      the elongated s type asteroid
# 8386                      the elongated s-type asteroid
# 8457                                the s type asteroid
# 8458                              the s - type asteroid
# 8804                     the carbonaceous type asteroid
# 8886                         the common s type asteroid
# 8887                       the common s - type asteroid
# 8982                     the carbonaceous type asteroid
# 9026               the likely elongated s type asteroid
# 9027               the likely elongated s-type asteroid
#
#                             relation  \
# 12          has a rotation period of
# 13                               has
# 152                              has
# 243    has a long rotation period of
# 244                              has
# 272                          deduced
# 325         has a rotation period of
# 326                              has
# 352    has a long rotation period of
# 546         has a rotation period of
# 547                              has
# 583         has a rotation period of
# 584                              has
# 670         has a rotation period of
# 671                              has
# 686         has a rotation period of
# 687                              has
# 696         has a rotation period of
# 697                              has
# 956         has a rotation period of
# 957                              has
# 1315        has a rotation period of
# 1316                             has
# 1480        has a rotation period of
# 1481                             has
# 1621                             has
# 2017   has a long rotation period of
# 2018                             has
# 2158        has a rotation period of
# 2159                             has
# ...                              ...
# 6672        has a rotation period of
# 6673                             has
# 6689        has a rotation period of
# 6690                             has
# 7021        has a rotation period of
# 7022                             has
# 7136        has a rotation period of
# 7137                             has
# 7315        has a rotation period of
# 7316                             has
# 7419   has a long rotation period of
# 7420                             has
# 7435        has a rotation period of
# 7436                             has
# 7706  has a short rotation period of
# 7707                             has
# 8051        has a rotation period of
# 8052                             has
# 8092  has a short rotation period of
# 8093                             has
# 8385        has a rotation period of
# 8386                             has
# 8457        has a rotation period of
# 8458                             has
# 8804        has a rotation period of
# 8886        has a rotation period of
# 8887                             has
# 8982        has a rotation period of
# 9026        has a rotation period of
# 9027                             has
#
#                                                    arg2   value  \
# 12                                          10.2 hours;   10.20
# 13    a rotation period of 10.2 hours approximately ...   10.20
# 152   a notably short rotation period of 3.0 hours a...    3.00
# 243                                        122.3 hours;  122.30
# 244   a long rotation period of 122.3 hours approxim...  122.30
# 272                         103 jpl ephemeris category;  103.00
# 325                                          3.6 hours;    3.60
# 326   a rotation period of 3.6 hours approximately i...    3.60
# 352                                         78.4 hours;   78.40
# 546                                          3.1 hours;    3.10
# 547                     a rotation period of 3.1 hours;    3.10
# 583                                        11.77 hours;   11.77
# 584                   a rotation period of 11.77 hours;   11.77
# 670                                        12.32 hours;   12.32
# 671                   a rotation period of 12.32 hours;   12.32
# 686                                         10.3 hours;   10.30
# 687                    a rotation period of 10.3 hours;   10.30
# 696                                         26.4 hours;   26.40
# 697   a rotation period of 26.4 hours approximately ...   26.40
# 956                                         10.6 hours;   10.60
# 957   a rotation period of 10.6 hours approximately ...   10.60
# 1315                                       16.19 hours;   16.19
# 1316                  a rotation period of 16.19 hours;   16.19
# 1480                                         5.1 hours;    5.10
# 1481  a rotation period of 5.1 hours approximately i...    5.10
# 1621           a very long rotation period of 80 hours;   80.00
# 2017                                          24 hours;   24.00
# 2018  a long rotation period of 24 hours approximate...   24.00
# 2158                                         9.0 hours;    9.00
# 2159                    a rotation period of 9.0 hours;    9.00
# ...                                                 ...     ...
# 6672                                         4.9 hours;    4.90
# 6673                    a rotation period of 4.9 hours;    4.90
# 6689                                        97.4 hours;   97.40
# 6690  a rotation period of 97.4 hours approximately ...   97.40
# 7021                                         7.8 hours;    7.80
# 7022                    a rotation period of 7.8 hours;    7.80
# 7136                                        7.88 hours;    7.88
# 7137                   a rotation period of 7.88 hours;    7.88
# 7315                                 at least 10 hours;   10.00
# 7316            a rotation period of at least 10 hours;   10.00
# 7419                                         130 hours;  130.00
# 7420               a long rotation period of 130 hours;  130.00
# 7435                                        5.95 hours;    5.95
# 7436                   a rotation period of 5.95 hours;    5.95
# 7706                                         3.3 hours;    3.30
# 7707              a short rotation period of 3.3 hours;    3.30
# 8051                                         8.5 hours;    8.50
# 8052                    a rotation period of 8.5 hours;    8.50
# 8092                                         2.5 hours;    2.50
# 8093              a short rotation period of 2.5 hours;    2.50
# 8385                                        12.3 hours;   12.30
# 8386                   a rotation period of 12.3 hours;   12.30
# 8457                                         5.4 hours;    5.40
# 8458  a rotation period of 5.4 hours approximately i...    5.40
# 8804                                        15.6 hours;   15.60
# 8886                                         7.5 hours;    7.50
# 8887  a rotation period of 7.5 hours approximately i...    7.50
# 8982                                       12.99 hours;   12.99
# 9026                                        3.53 hours;    3.53
# 9027                   a rotation period of 3.53 hours;    3.53
#
#                   unit  measure     quantity
# 12                hour     time   10.2 hours
# 13                hour     time   10.2 hours
# 152               hour     time    3.0 hours
# 243               hour     time  122.3 hours
# 244               hour     time  122.3 hours
# 272   joule pint litre  unknown      103 jpl
# 325               hour     time    3.6 hours
# 326               hour     time    3.6 hours
# 352               hour     time   78.4 hours
# 546               hour     time    3.1 hours
# 547               hour     time    3.1 hours
# 583               hour     time  11.77 hours
# 584               hour     time  11.77 hours
# 670               hour     time  12.32 hours
# 671               hour     time  12.32 hours
# 686               hour     time   10.3 hours
# 687               hour     time   10.3 hours
# 696               hour     time   26.4 hours
# 697               hour     time   26.4 hours
# 956               hour     time   10.6 hours
# 957               hour     time   10.6 hours
# 1315              hour     time  16.19 hours
# 1316              hour     time  16.19 hours
# 1480              hour     time    5.1 hours
# 1481              hour     time    5.1 hours
# 1621              hour     time     80 hours
# 2017              hour     time     24 hours
# 2018              hour     time     24 hours
# 2158              hour     time    9.0 hours
# 2159              hour     time    9.0 hours
# ...                ...      ...          ...
# 6672              hour     time    4.9 hours
# 6673              hour     time    4.9 hours
# 6689              hour     time   97.4 hours
# 6690              hour     time   97.4 hours
# 7021              hour     time    7.8 hours
# 7022              hour     time    7.8 hours
# 7136              hour     time   7.88 hours
# 7137              hour     time   7.88 hours
# 7315              hour     time     10 hours
# 7316              hour     time     10 hours
# 7419              hour     time    130 hours
# 7420              hour     time    130 hours
# 7435              hour     time   5.95 hours
# 7436              hour     time   5.95 hours
# 7706              hour     time    3.3 hours
# 7707              hour     time    3.3 hours
# 8051              hour     time    8.5 hours
# 8052              hour     time    8.5 hours
# 8092              hour     time    2.5 hours
# 8093              hour     time    2.5 hours
# 8385              hour     time   12.3 hours
# 8386              hour     time   12.3 hours
# 8457              hour     time    5.4 hours
# 8458              hour     time    5.4 hours
# 8804              hour     time   15.6 hours
# 8886              hour     time    7.5 hours
# 8887              hour     time    7.5 hours
# 8982              hour     time  12.99 hours
# 9026              hour     time   3.53 hours
# 9027              hour     time   3.53 hours
#
# [126 rows x 8 columns]

# %%
df2.groupby(["relation","unit"])['value'].agg(["min","max","count"]).sort_values("count", ascending=False)#.query("count > 10")
# Out:
#                                                         min    max  count
# relation                           unit
# has                                hour                2.50  130.0     62
# has a rotation period of           hour                2.95   97.4     50
# has a long rotation period of      hour               24.00  130.0      6
# has a short rotation period of     hour                2.50    4.9      4
# composed                           percentage         65.00   65.0      2
# deduced                            joule pint litre  103.00  103.0      1
# has a tentative rotation period of hour               15.00   15.0      1
